# %% [markdown]
# Task 1: Hough transform for document skew estimation

# %% [markdown]
# I’m estimating the skew angle of a document image using the Hough transform. I load the image, binarize it, and create a negative version. Then, I select candidate points, apply the Hough transform to detect lines, calculate the median angle, and deskew the image.

# %%
import cv2 as cv
import numpy as np

def load_and_binarize(image_path, threshold=200):
    img = cv.imread(image_path, 0)
    _, doc_bin = cv.threshold(img, threshold, 255, cv.THRESH_BINARY)
    return img, doc_bin

def get_negative(binary_image):
    return 255 - binary_image

def extract_connected_components(binary_image):
    return cv.connectedComponentsWithStats(binary_image)

if __name__ == "__main__":
    image_path = 'doc.jpg'
    original, binary = load_and_binarize(image_path)
    negative = get_negative(binary)
    num_labels, labels, stats, centroids = extract_connected_components(negative)

    cv.imwrite('original.jpg', original)
    cv.imwrite('binary.jpg', binary)
    cv.imwrite('negative.jpg', negative)

    print(f"Number of connected components: {num_labels}")
# Out:
# Number of connected components: 3972

# %%
import numpy as np
import cv2 as cv
import time

def select_candidate_points(strategy, negative, num_labels, labels, centroids):
    if strategy == 'a':
        return np.column_stack(np.where(negative > 0))
    elif strategy == 'b':
        return centroids[1:]
    elif strategy == 'c':
        candidate_points = []
        for label in range(1, num_labels):
            component = np.where(labels == label)
            max_y = np.max(component[0])
            x = component[1][np.argmax(component[0])]
            candidate_points.append([x, max_y])
        return np.array(candidate_points)
    else:
        raise ValueError("Invalid strategy. Choose 'a', 'b', or 'c'.")

def remove_non_candidates(shape, candidate_points):
    result = np.zeros(shape)
    for point in candidate_points:
        x, y = point
        if 0 <= x < shape[1] and 0 <= y < shape[0]:
            result[int(y), int(x)] = 255
    return result

if __name__ == "__main__":
    negative = cv.imread('negative.jpg', 0)
    num_labels, labels, stats, centroids = cv.connectedComponentsWithStats(negative)

    strategies = ['a', 'b', 'c']
    for strategy in strategies:
        start_time = time.time()
        candidate_points = select_candidate_points(strategy, negative, num_labels, labels, centroids)
        selection_time = time.time() - start_time

        result = remove_non_candidates(negative.shape, candidate_points)
        cv.imwrite(f'candidate_points_{strategy}.jpg', result)

        print(f"Strategy {strategy}:")
        print(f"  Number of candidate points: {len(candidate_points)}")
        print(f"  Selection time: {selection_time:.4f} seconds")
# Out:
# Strategy a:
#   Number of candidate points: 414800
#   Selection time: 0.0148 seconds
# Strategy b:
#   Number of candidate points: 6058
#   Selection time: 0.0001 seconds
# Strategy c:
#   Number of candidate points: 6058
#   Selection time: 26.6902 seconds

# %%
import cv2 as cv
import numpy as np
import statistics
import time

def apply_hough_transform(binary_image, distance_resolution=1, angular_resolution=np.pi/180, density_threshold=10):
    return cv.HoughLines(binary_image, distance_resolution, angular_resolution, density_threshold)

def calculate_document_angle(lines):
    if lines is not None:
        angles = [line[0][1] for line in lines]
        median_angle = statistics.median(angles)
        document_angle = np.pi/2 - median_angle
        return np.degrees(document_angle)
    return 0

def deskew_image(image, angle):
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv.getRotationMatrix2D(center, -angle, 1.0)
    return cv.warpAffine(image, M, (w, h), flags=cv.INTER_CUBIC, borderMode=cv.BORDER_REPLICATE)

if __name__ == "__main__":
    original = cv.imread('original.jpg', 0)
    strategies = ['a', 'b', 'c']
    density_thresholds = [5, 10, 20]

    for strategy in strategies:
        for threshold in density_thresholds:
            candidate_points = cv.imread(f'candidate_points_{strategy}.jpg', 0)

            start_time = time.time()
            lines = apply_hough_transform(candidate_points, density_threshold=threshold)
            hough_time = time.time() - start_time

            angle = calculate_document_angle(lines)
            deskewed = deskew_image(original, angle)

            cv.imwrite(f'deskewed_{strategy}_{threshold}.jpg', deskewed)

            print(f"Strategy: {strategy}, Density Threshold: {threshold}")
            print(f"  Estimated angle: {angle:.2f} degrees")
            print(f"  Hough transform time: {hough_time:.4f} seconds")
# Out:
# Strategy: a, Density Threshold: 5
#   Estimated angle: 5.00 degrees
#   Hough transform time: 0.0558 seconds
# Strategy: a, Density Threshold: 10
#   Estimated angle: 5.00 degrees
#   Hough transform time: 0.0530 seconds
# Strategy: a, Density Threshold: 20
#   Estimated angle: 5.00 degrees
#   Hough transform time: 0.0534 seconds
# Strategy: b, Density Threshold: 5
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0187 seconds
# Strategy: b, Density Threshold: 10
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0181 seconds
# Strategy: b, Density Threshold: 20
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0176 seconds
# Strategy: c, Density Threshold: 5
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0194 seconds
# Strategy: c, Density Threshold: 10
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0195 seconds
# Strategy: c, Density Threshold: 20
#   Estimated angle: -0.00 degrees
#   Hough transform time: 0.0188 seconds

# %%
import cv2 as cv
import pytesseract
import time

def perform_ocr(image):
    return pytesseract.image_to_string(image)

def generate_pdf(image, output_path):
    pdf = pytesseract.image_to_pdf_or_hocr(image, extension='pdf')
    with open(output_path, 'w+b') as f:
        f.write(pdf)

if __name__ == "__main__":
    original = cv.imread('original.jpg')
    strategies = ['a', 'b', 'c']
    density_thresholds = [5, 10, 20]

    # Process original image
    start_time = time.time()
    original_text = perform_ocr(original)
    ocr_time = time.time() - start_time

    print("Original Image OCR:")
    print(original_text)
    print(f"OCR Time: {ocr_time:.4f} seconds")

    generate_pdf(original, 'original.pdf')

    # Process deskewed images
    for strategy in strategies:
        for threshold in density_thresholds:
            deskewed = cv.imread(f'deskewed_{strategy}_{threshold}.jpg')
            
            start_time = time.time()
            deskewed_text = perform_ocr(deskewed)
            ocr_time = time.time() - start_time

            print(f"\nDeskewed Image OCR (Strategy: {strategy}, Threshold: {threshold}):")
            print(deskewed_text)
            print(f"OCR Time: {ocr_time:.4f} seconds")

            generate_pdf(deskewed, f'deskewed_{strategy}_{threshold}.pdf')

    # Process test images
    test_images = ['01.jpg', '02.jpg', '03.jpg', '04.jpg', '05.jpg']
    for test_image in test_images:
        img = cv.imread(test_image)
        
        start_time = time.time()
        test_text = perform_ocr(img)
        ocr_time = time.time() - start_time

        print(f"\nOCR Result for {test_image}:")
        print(test_text)
        print(f"OCR Time: {ocr_time:.4f} seconds")

        generate_pdf(img, f'{test_image[:-4]}.pdf')
# Out:
# Original Image OCR:
# A Fielg Mode fo Pairing 3D Shapes«
# Uc Thanh Neuyent2 Binh-s a", Mi Oi Tray 2) Quang. lieu m?, and Sai-Kit Yeung?
# 180 OO! of I, n logy, Deakin University Australia
# Manor Univ, ty of hnolog id sign, M8apore
# Abstract
# This: pay, So Rel moges L ePairing 3p)
# Shapes ¢ ‘Onstriy rom Multi-vioy, RGR data, pecificalty
# we "Present q 3 Shape in @ Mar, ov aNdom, Mi i
# Which the SeOMetric infoyy ation is en
# oY Variables a
# |
#
# {7}, p, Vi.
# by Perform in,
# 8, ), Ve enableg This Proce:
# Scene data and this ‘aS raiseg be defi
# Sented in an
# When Duc Thanh Neuyen wag Working ap
# mology ang Design,
#
# OCR Time: 0.7699 seconds
#
# Deskewed Image OCR (Strategy: a, Threshold: 5):
#
# OCR Time: 0.4316 seconds
#
# Deskewed Image OCR (Strategy: a, Threshold: 10):
#
# OCR Time: 0.4129 seconds
#
# Deskewed Image OCR (Strategy: a, Threshold: 20):
#
# OCR Time: 0.4097 seconds
#
# Deskewed Image OCR (Strategy: b, Threshold: 5):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.5706 seconds
#
# Deskewed Image OCR (Strategy: b, Threshold: 10):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.5690 seconds
#
# Deskewed Image OCR (Strategy: b, Threshold: 20):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.5642 seconds
#
# Deskewed Image OCR (Strategy: c, Threshold: 5):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.5623 seconds
#
# Deskewed Image OCR (Strategy: c, Threshold: 10):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.6802 seconds
#
# Deskewed Image OCR (Strategy: c, Threshold: 20):
# 2
#
# > Quang. lieu m?, and Sai-Kit Yeung?
# a logy, D, akin University, Australia
# Manor, Univ, ty of hnolog id Sign, 8apore
# Abstract
# This pa Sa fielg Model
# Shapes ¢ ONStriy, €d from Multi yj,
# WE repre s y di
#
# n 3D data Analysis. However
# Pens that the 3 data Cannot be i
# * Variationgy Shown in Fig. 1), even b
# Inique is sabe for the agin eg. [4 :
# Proposed Method ‘as Valuated on both
# ed rea] COnStruction
# lave 5s, “OWN the
# thod
#
# "” repair.
#
# ), have enableg
# data ang this hag Taiseq
#
# Sented in an
# When Dug Thanh Neuyen wag Working ap
# mology ang Design,
#
#
# OCR Time: 0.6719 seconds
#
# OCR Result for 01.jpg:
# The Intelligent Investor
#
# past 20 years ha:
# eyed. what once were Re Sa eS the
# mitted ie successfull exploitation lished day
# and selling high. Whether he applvingadat
# Y tems
#
# for buyiNS
# -market pattem will eventu
# alls .
# y retum We he:
#
# pull-and-beat
# know: But} ealistic to Us for the investi
# : - om the classic form ia endeavyn
# t \evels before divine 5 wit ty
# ded policy has, nNieveunte COttng
# rtion of common stocks to 1S Boag
# to do so, according as ea
# i)
#
# chooses
# less oF more attractive by value
# stan.
#
# ior in the
#
# that began in 195-4)
# 5 methods of taking
# have been knowns
#
# gtock-market rise
# a to yariou'
#
# . These
# e of all such plans—exen
#
# 99-8!)
#
# aot
#
#
# OCR Time: 3.4412 seconds
#
# OCR Result for 02.jpg:
# Mo 8h
# St of E 5% ; N 209,°u
# Brit; he a. *0dugig 9 200, 209
# Fitigh t as MPan us fileg F 009 ang Sar a Gg
# er © the p MUnicat Sees y, Chante, 8%; t Sy
# @ar| fOmis iong 0:88 bo 1 ben 200
# Share 003. ress E Sat In tec ant by thy 9
# in hem ec: Sliven. Wing clo
# Bxodug’ SXileg iy "Ing it "elegy i
# Stoo ew Shag \)
# Wag Ider Ne
#
# . vestor
# we : n for the pefensive y
#
# Pig £ the techniques of
# oadet applicaserribed in general terms
# ave alrea 4 for our two categories of
#
# ae ow to indicate how security
# a ve implement these policies. The
# Ne estions Will purchase only
# a leading common stocks.
# he bought the latter is
# applicable standards. . ;
# this diversified list he has a choice OF two
# a pjlA-type of portfolio and the quantitatively-
# jo. In the first he acquires a true cross-section sample
# no jsgues, Which will include both some favored growth
# companies, whose shares sell at especially high multipliers, and
# ako less popular and less expensive enterprises. This could be
# jae, most simply perhaps, by buying the same amounts of all
# thirty of the issues In the Dow-Jones Industrial Average (DJIA). Ten
# f each, at the 900 level for the ee
# ie ih average, would cost an
# pptegate of about $16,000.' On the basis of the past record he
#
# might expect approximately the same f
# uture results ing
# stares of several representative investment funds.t by buying
#
# His second choi
# tond choice would be to apply a set of standards to each
#
# “Graham describe
#
# 8 his reco i
# hugh mmended investment policies in Chapters 4
# ers
#
#
# OCR Time: 3.9839 seconds
#
# OCR Result for 03.jpg:
# The one to play 1s the one that
# y dont know which that is Yours
#
# e it out. But if you do this wnt
# achines: Conversely, if sn 50
# good by chance on hes ge
#
# & hry. :
# one You was® youn Daynge We
# plorsvORs eRe Oram lemma
# e betwee® repeating the bes y,
# Ny,
# the best payofl, or trying a
# ay ne s oe ore
# t the opt
#
# aca where the coin Hecomes exponent
#
# me if it Aoesnt work for yn,
# ¢ wins the end.) The better ai, a
# it, DUE nevet completely gr ee
# pest one after al. te you”
# group of gatttler, | ane if
# e same came. W We 2 com
#
# pn at th
# qne game Dis and dite
#
# minutes defore gmishing, 1S
# only guess at the question
#
# gnould you play’
#
#
# OCR Time: 3.4602 seconds
#
# OCR Result for 04.jpg:
# 198 | ee Cony),
#
# YOU ARE WHAT YOU RESEMBLE | 199
#
# Music ©OMPosition.
#
# higher up in the skills ladder js
# bly even e University of Ca]-
#
# eritus professor of music at th
# an em
#
# Agua
# Cope Cruz, designed an algorithm that Creates new Music jn
# uz,
# Santa
#
# vid
# pa famous composers by Selecting ang recombining short
# ine style of fam attended some Years ago,
#
# from their work. At a EG)
# assages fT Pieces: one by the Teal Mozart One by a hy-
#
# : played three “Mozart
# he itati
#
# : delighted. Audiences at
# audience was delig ‘
#
# le 6 tt 1 :
#
# » Say, a
#
# media company to a “onsumer-products One without Starting from
#
# scratch because many of the same Management Skills stil] apply. Wall
#
# Street hires lots of Physicists } ysical and financial Problems,
#
# although superficially very different, often have a similar mathematj-
#
# cal structure. Yet all the learners We've seen so far would fal] flat if
# Predict Brownian mo
#
# ome of their parts and Trela-
# €, transfers further Prop-
#
# € to the other. For example, if the structures are
# | om, We can map planets to electrons and the
# ne as Bohr did, that electrons Tevolve
# uth is more subtle, of course, and We often
# Molat: e them. But being able to learn
#
# a key attribute of a UNiversa]
#
# at correspondenc
#
#
# OCR Time: 3.6976 seconds
#
# OCR Result for 05.jpg:
# gvOLUTION NATURE'S LEARNING ALGORITHM Van
# 35
# ’ Woulg hay, j the search becomes a type of hill anes
# he ;ations, pick the best one, and epee (Ge © = all
# i ; ations, in which case it’s called beam sear < sev-
# use this all the time to learn sets of rules ies
# fort OF Cvoronio™: 10 avoid getting Sancre
# im
#
# | THE MASTER ALGORITHM
#
# 134
# st, then Janua
# BY AS)
#
# instead ofa conversationali
# date for the history books.
# Koza’ confidence stands out even in a fielg A
# ing violets. He sees genetic i ogramming as an (noma fo,
# : n tj
# silicon Edison for a ees pn? He ang ont mig hiss
# believe it can a Ca nena M8 it their eng... °Vol “ting 4 of it a8 4
# gorithm eae es. es a x instituted the ey in the Ut me ; climbing can be enhanced with randomness (ea
# to recognize uman P genetic Creation - Hum, y with some probability) and random restarts (aft ;
# been awarded to date. SS thin i dom state and continue from th ms
# : "Y-nin ‘4 a d solutions to probl Mere). Doing this
# e { solutio oblems; whi ‘
# ha, Be Wee aextrace a ether the benefit of
# o it justiles mputational cost remains an
# hy sex 1S ae in nature, either. Several theories
# ut none is wide y accepted. The leader of the pack
# popularized by Matt Ridley in the epon-
# set great ; the Red ORs said to Alice in Through the Looking
# not worth the trouble. None of Holland’s theoretj ibes thing the running you can do, to keep in the same place”
# : ca. r , 2 o ‘ :
# _ crossover actually helps; mutation suffices to exponent te show, 4 organisms a 3 a Pare race ae parasites, and
# é ally ; it opulation varie , so that no single :
# frequency of the fittest schemas in the population oye, NCteasg the : ee : ae then sex is irrelevant d ee ae
# “building blocks” intuition is appealing but quickly ryp Ime. Ang h ne : ee en en machine learning,
# oe aya! S$ j ‘ r com ‘
# even when genetic programming is used. As larger bl Into troup, until learne prog a: : puter viruses for
# ; Ocks evoly, s . ne and memory: (Intriguingly, Danny Hillis claims that de-
# also becomes increasingly likely to break them ween € ctog, coevolving parasites into a genetic algorith
# * Also, ong g genetic algorithm can
# 4 ape local maxima by gradually ratcheting up the difficulty,
# owed up on this yet.) Christos Papadimitriou and
# x optimizes not fitness but what they call
#
# ave shown that se
# ability to do well on average when combined with
#
# be useful when the fitness function is either not
# natural selection, but in machine learning
#
# What is sex for?
# sure W
#
# Despite their successes, and the insights they've wee
# gradualism versus punctuated equilibria, genetic Aes On ig
# one great mystery unsolved: the role of sex in Coes Srithms hay
# store by crossover, but members of the o then eho :
# df
#
# over
# highly fit individual appears, its descendants tend to quick
# y take Ov
# a 9 one has foll
#
# hat Ver put 0
#
# the population, crowding out potentially better schemas ;
# colleagues h
#
# trapped in overall less fit individuals. This effectively reduces th
# * ” ;
# to variations of the fitness champ. Researchers have come up a bility: a genes
# With a mixa ;
# other genes: This can
#
# number of schemes for preserving diversity in the population, but
# } (
# known or not constant, as in
# hill climbing tends to do better.
# ing do not end there. Indeed,
#
# results so far are inconclusive. Engineers certainly use building bloc
# extensively, but combining them involves, well, a lot of engineering i | and optimization,
#
# The problems for genetic programm
#
# netic as evolutionaries would like.
#
# x of throwing them together any old way, and its ni |
# , even its successes might not be as ge
# e circuit design, which was genetic programmings emblematic
# yen relatively simple designs require an enormous
#
#
# OCR Time: 5.4144 seconds
